# %%
""" So this is a testing ground of code to use for my project 2"""
# i have decided to do the raw data here, and format it later
#Make 2 menues, one for errors and one for the actual program

''' Currently need
 while loop
 





'''

#copy and paste this code

import csv
import datetime as dt
import time

# %%
# Import the csv module, datetime module
import csv
import datetime as dt
import time


print("Welcome to the Contact List Program")
print("please choose from the following options below: ")
print("--------------------------------------------------")
print("press 1 to Add contact")
print("press 2 to View contacts")
print("press 3 to Delete contact")
print("press 4 to Save contacts to csv file")
print("press 5 to Next Birthday")
print("press 0 to Quit")
print("--------------------------------------------------")
print("\n")
imput = input("Please enter your choice: ")
if imput == "1":
        add_contact()
elif imput == "2":
        view_contacts()
elif imput == "3":
        delete_contact()
elif imput == "4":
        save_csv()
elif imput == "5":
        next_birthday()
elif imput == "0":
    print("Thank you for using the Contact List Program")
    time.sleep(2)
    print("Goodbye")
    quit()

else:
    print("Invalid input")
    exaustion = False

# %%
# Import the csv module, datetime module
import csv
import datetime as dt
import time
def menue():
    print("Welcome to the Contact List Program")
    print("please choose from the following options below: ")
    print("--------------------------------------------------")
    print("press 1 to Add contact")
    print("press 2 to View contacts")
    print("press 3 to Delete contact")
    print("press 4 to Save contacts to csv file")
    print("press 5 to Next Birthday")
    print("press 0 to Quit")
    print("--------------------------------------------------")
    print("\n")
imput = input("Please enter your choice: ")
if imput == "1":
    try:
        add_contact()
    except:
        print("Error")
        
elif imput == "2":
    try:
        view_contacts()
    except:
        print("Error")
elif imput == "3":
    try:
        delete_contact()
    except:
        print("Error")
elif imput == "4":
    try:
        save_csv()
    except:
        print("Error")
elif imput == "5":
    try:
        next_birthday()
    except:
        print("Error")
elif imput == "0":
    try:
        print("Thank you for using the Contact List Program")
        time.sleep(2)
        print("Goodbye")
        quit()
    except:
        print("Error")
else:
    try:
        print("Invalid input")
        exaustion = False
    except:
        print("Error")
