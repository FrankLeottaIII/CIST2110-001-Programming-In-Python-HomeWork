# %%
""" So this is a testing ground of code to use for my project 2"""

# before that
"""
lab 10 due next tues, the 28th
then this project is due on the 5th...
then work on project 3  Jesus Christ


"need to convert 
"""

# i have decided to do the raw data here, and format it later... actual funtions will be in the other individual files

#I will idiotproof it later, right now I cant waste time on that









''' Currently need
 while loop
 





'''

#copy and paste this code

import csv
import datetime as dt
import time

# %%
import csv
#REFRESHER ON DICTIONARIES
#dictionaries are a collection of key value pairs
#dictionaries are mutable
#dictionaries are unordered
#dictionaries are indexed by keys (not by numbers)
#dictionaries are defined by curly braces {}
#dictionaries are accessed by keys
#dictionaries are comma separated key:value pairs
#dictionaries are accessed by keys

#and example of a dictionary
water = {'H20': 'water', 'NaCl': 'salt', 'CO2': 'carbon dioxide'}
print(water)
print(water['NaCl'])
 
#adding a new key:value pair to a dictionary
water['H2O2'] = 'hydrogen peroxide'
print(water)

#grabbing info from a cvs file
#open the file

# Open the CSV file
with open('filename.csv', 'r') as file:
    # Create a CSV reader object
    reader = csv.reader(file)

    # Iterate over each row in the CSV file
    for row in reader:
        # Access the data in each column
        column1 = row[0]
        column2 = row[1]
        # Process the data as needed
        # ...
# Out:
# {'H20': 'water', 'NaCl': 'salt', 'CO2': 'carbon dioxide'}
# salt
# {'H20': 'water', 'NaCl': 'salt', 'CO2': 'carbon dioxide', 'H2O2': 'hydrogen peroxide'}

# %%
# Import the csv module, datetime module
import csv
import datetime as dt
import time


print("Welcome to the Contact List Program")
print("please choose from the following options below: ")
print("--------------------------------------------------")
print("press 1 to Add contact")
print("press 2 to View contacts")
print("press 3 to Delete contact")
print("press 4 to Save contacts to csv file")
print("press 5 to Next Birthday")
print("press 0 to Quit")
print("--------------------------------------------------")
print("\n")
imput = input("Please enter your choice: ")
if imput == "1":
        add_contact()
elif imput == "2":
        view_contacts()
elif imput == "3":
        delete_contact()
elif imput == "4":
        save_csv()
elif imput == "5":
        next_birthday()
elif imput == "0":
    print("Thank you for using the Contact List Program")
    time.sleep(2)
    print("Goodbye")
    quit()

else:
    print("Invalid input")
    exaustion = False

# %%
# Import the csv module, datetime module
import csv
import datetime as dt
import time
def menue():
    print("Welcome to the Contact List Program")
    print("please choose from the following options below: ")
    print("--------------------------------------------------")
    print("press 1 to Add contact")
    print("press 2 to View contacts")
    print("press 3 to Delete contact")
    print("press 4 to Save contacts to csv file")
    print("press 5 to Next Birthday")
    print("press 0 to Quit")
    print("--------------------------------------------------")
    print("\n")
imput = input("Please enter your choice: ")
if imput == "1":
    try:
        add_contact()
    except:
        print("Error")
        
elif imput == "2":
    try:
        view_contacts()
    except:
        print("Error")
elif imput == "3":
    try:
        delete_contact()
    except:
        print("Error")
elif imput == "4":
    try:
        save_csv()
    except:
        print("Error")
elif imput == "5":
    try:
        next_birthday()
    except:
        print("Error")
elif imput == "0":
    try:
        print("Thank you for using the Contact List Program")
        time.sleep(2)
        print("Goodbye")
        quit()
    except:
        print("Error")
else:
    try:
        print("Invalid input")
        exaustion = False
    except:
        print("Error")
